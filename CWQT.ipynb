# %%
import pandas as pd
import numpy as np
from scipy import stats 
import matplotlib.pyplot as plt 
import re


# Loading the data from the excel sheet

xls = pd.ExcelFile('CWQT_Master_DataSheet.xlsx')
df = pd.read_excel(xls, 'Data')

# %%
# Only taking the data for hudson river, Pier 66
# hudsonDf = df.loc[df["Site"] == "Hudson River, Pier 66"]

# %%
# Dropping the notes column
# hudsonDf = hudsonDf.drop(["Notes"], axis=1)

# %%
# hudsonDf hudsonDf[["Day of Collection Precipitation (Thursday)"]].replace("Trace", 0)

# replacing all the trace with value of 0 
# replacedTraceDF = hudsonDf.replace("Trace", 0)

# %%
# printing the info of the data 
# replacedTraceDF.info()

# %%
# replacedTraceDF["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"]

# %%
# replacedTraceDF

# (df["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"] == "<10").value_counts()

# %%
# (df["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"] == ">24196").value_counts()

# %%
# replacedTraceDF

# %%
# replacedTraceDF['Year'].value_counts()

# %%
df["Year"].value_counts()
# Out:
# 2021    1327
# 2019    1283
# 2018    1194
# 2017    1116
# 2016     903
# 2015     880
# 2014     674
# 2013     580
# 2020     568
# 2012     377
# 2011      50
# Name: Year, dtype: int64

# %%
# df["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"] = df[["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"]].replace("<10", 10)
# df["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"] = df["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"].replace(">24196", 24196)
# df["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"] = df["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"].replace(">6000", 6000)

df = df.drop(df[(df["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"] == "<10") \
                | (df["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"] == ">24196") \
                | (df["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"] == ">6000")].index)




df  = df.replace("Trace", 0)
df = df.drop(["Notes"], axis=1)


hudsonDf = df.loc[df["Site"] == "Hudson River, Pier 66"]



hudsonDf
# Out:
#                        Site  Full Date  Year  Month Battery High Tide  \
# 0     Hudson River, Pier 66 2011-10-20  2011     10          02:33:00
# 8     Hudson River, Pier 66 2011-10-27  2011     10          08:51:00
# 21    Hudson River, Pier 66 2011-11-09  2011     11          06:57:00
# 27    Hudson River, Pier 66 2011-11-17  2011     11          00:15:00
# 31    Hudson River, Pier 66 2011-11-21  2011     11          04:01:00
# ...                     ...        ...   ...    ...               ...
# 8663  Hudson River, Pier 66 2021-09-02  2021      9          05:35:00
# 8717  Hudson River, Pier 66 2021-09-09  2021      9          10:29:00
# 8783  Hudson River, Pier 66 2021-09-16  2021      9          05:02:00
# 8843  Hudson River, Pier 66 2021-09-23  2021      9          10:34:00
# 8905  Hudson River, Pier 66 2021-09-30  2021      9          03:59:00
#
#      Sample Time  \
# 0       14:43:00
# 8       11:17:00
# 21      13:40:00
# 27      10:14:00
# 31      10:47:00
# ...          ...
# 8663    10:28:00
# 8717    10:10:00
# 8783    09:53:00
# 8843    09:56:00
# 8905    09:58:00
#
#       Most Probable Number (MPN) of Enterococcus colonies per 100 ml  \
# 0                                                    31
# 8                                                    31
# 21                                                  979
# 27                                                  446
# 31                                                   10
# ...                                                 ...
# 8663                                               1439
# 8717                                                 31
# 8783                                                 51
# 8843                                                 73
# 8905                                                 10
#
#      Day of Collection Precipitation (Thursday)  \
# 0                                          0.01
# 8                                          0.63
# 21                                            0
# 27                                         0.07
# 31                                         0.12
# ...                                         ...
# 8663                                        0.1
# 8717                                       0.26
# 8783                                          0
# 8843                                       1.37
# 8905                                          0
#
#      Previous Day Precipitation (Wednesday) Previous Tuesday Precipitation  \
# 0                                      1.12                           0.01
# 8                                         0                              0
# 21                                        0                              0
# 27                                     0.73                              0
# 31                                        0                              0
# ...                                     ...                            ...
# 8663                                   7.13                              0
# 8717                                      0                              0
# 8783                                      0                              0
# 8843                                   0.02                           0.09
# 8905                                      0                           0.27
#
#      Previous Monday Precipitation Previous Sunday Precipitation  \
# 0                                0                             0
# 8                                0                             0
# 21                               0                             0
# 27                               0                             0
# 31                               0                          0.07
# ...                            ...                           ...
# 8663                             0                             0
# 8717                             0                          0.02
# 8783                          0.12                             0
# 8843                             0                             0
# 8905                             0                             0
#
#       Previous Saturday Precipitation Previous Friday Precipitation
# 0                                0.00                             0
# 8                                0.00                             0
# 21                               0.00                             0
# 27                               0.00                             0
# 31                               0.73                             0
# ...                               ...                           ...
# 8663                             0.00                          0.67
# 8717                             0.00                             0
# 8783                             0.00                             0
# 8843                             0.00                             0
# 8905                             0.00                          0.66
#
# [138 rows x 14 columns]

# %%
# (df["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"] > 30).value_counts()

# %% [markdown]
# - df["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"] = df[["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"]].replace("<10", 10)
#
# - df["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"] = df["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"].replace(">24196", 24196)
#
# - df["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"] = df["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"].replace(">6000", 6000)

# %%
df = df.replace("Trace", 0)

# %%
df["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"].astype(int)
# Out:
# 0        31
# 1       624
# 2       826
# 3       826
# 4       876
#        ...
# 8946     41
# 8947     20
# 8949     10
# 8950     20
# 8951     10
# Name: Most Probable Number (MPN) of Enterococcus colonies per 100 ml, Length: 7382, dtype: int64

# %%
# df.loc[df["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"] > 104][["Day of Collection Precipitation (Thursday)"]] 

# df.loc[df["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"] > 104][["Day of Collection Precipitation (Thursday)"]] 

# df["High"] =  df["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"] > 104
# df["Low"] =  df["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"] < 35
# df["High"] =  df["Most Probable Number (MPN) of Enterococcus colonies per 100 ml"] > 104

# %%
df
# df  = df.replace("Trace", 0)
df.groupby(["Year"]).mean()
# Out:
#           Month  \
# Year
# 2011  10.883721
# 2012   7.351916
# 2013   7.350943
# 2014   7.299658
# 2015   7.313390
# 2016   7.345697
# 2017   7.198614
# 2018   7.475504
# 2019   7.400000
# 2020   8.042129
# 2021   7.172352
#
#       Most Probable Number (MPN) of Enterococcus colonies per 100 ml  \
# Year
# 2011                                         678.000000
# 2012                                         425.944251
# 2013                                         506.807547
# 2014                                         417.950342
# 2015                                         559.763533
# 2016                                         438.869436
# 2017                                         423.627021
# 2018                                        1040.183477
# 2019                                        1284.910092
# 2020                                        1024.263858
# 2021                                         840.068223
#
#       Previous Saturday Precipitation
# Year
# 2011                         0.118837
# 2012                         0.092265
# 2013                         0.071415
# 2014                         0.061695
# 2015                         0.136610
# 2016                         0.115593
# 2017                         0.310231
# 2018                         0.131796
# 2019                         0.012716
# 2020                         0.036763
# 2021                         0.334740

# %%
xls = pd.ExcelFile('CWQT_Master_DataSheet.xlsx')
df = pd.read_excel(xls, 'Data')

df = df.replace("Trace", 0)
df = df.drop(["Notes"], axis=1)


hudsonDf = df.loc[df["Site"] == "Hudson River, Pier 66"]



hudsonDf
# Out:
#                        Site  Full Date  Year  Month Battery High Tide  \
# 0     Hudson River, Pier 66 2011-10-20  2011     10          02:33:00
# 8     Hudson River, Pier 66 2011-10-27  2011     10          08:51:00
# 21    Hudson River, Pier 66 2011-11-09  2011     11          06:57:00
# 27    Hudson River, Pier 66 2011-11-17  2011     11          00:15:00
# 31    Hudson River, Pier 66 2011-11-21  2011     11          04:01:00
# ...                     ...        ...   ...    ...               ...
# 8663  Hudson River, Pier 66 2021-09-02  2021      9          05:35:00
# 8717  Hudson River, Pier 66 2021-09-09  2021      9          10:29:00
# 8783  Hudson River, Pier 66 2021-09-16  2021      9          05:02:00
# 8843  Hudson River, Pier 66 2021-09-23  2021      9          10:34:00
# 8905  Hudson River, Pier 66 2021-09-30  2021      9          03:59:00
#
#      Sample Time  \
# 0       14:43:00
# 8       11:17:00
# 21      13:40:00
# 27      10:14:00
# 31      10:47:00
# ...          ...
# 8663    10:28:00
# 8717    10:10:00
# 8783    09:53:00
# 8843    09:56:00
# 8905    09:58:00
#
#      Most Probable Number (MPN) of Enterococcus colonies per 100 ml  \
# 0                                                    31
# 8                                                    31
# 21                                                  979
# 27                                                  446
# 31                                                   10
# ...                                                 ...
# 8663                                               1439
# 8717                                                 31
# 8783                                                 51
# 8843                                                 73
# 8905                                                 10
#
#      Day of Collection Precipitation (Thursday)  \
# 0                                          0.01
# 8                                          0.63
# 21                                            0
# 27                                         0.07
# 31                                         0.12
# ...                                         ...
# 8663                                        0.1
# 8717                                       0.26
# 8783                                          0
# 8843                                       1.37
# 8905                                          0
#
#      Previous Day Precipitation (Wednesday) Previous Tuesday Precipitation  \
# 0                                      1.12                           0.01
# 8                                         0                              0
# 21                                        0                              0
# 27                                     0.73                              0
# 31                                        0                              0
# ...                                     ...                            ...
# 8663                                   7.13                              0
# 8717                                      0                              0
# 8783                                      0                              0
# 8843                                   0.02                           0.09
# 8905                                      0                           0.27
#
#      Previous Monday Precipitation Previous Sunday Precipitation  \
# 0                                0                             0
# 8                                0                             0
# 21                               0                             0
# 27                               0                             0
# 31                               0                          0.07
# ...                            ...                           ...
# 8663                             0                             0
# 8717                             0                          0.02
# 8783                          0.12                             0
# 8843                             0                             0
# 8905                             0                             0
#
#       Previous Saturday Precipitation Previous Friday Precipitation
# 0                                0.00                             0
# 8                                0.00                             0
# 21                               0.00                             0
# 27                               0.00                             0
# 31                               0.73                             0
# ...                               ...                           ...
# 8663                             0.00                          0.67
# 8717                             0.00                             0
# 8783                             0.00                             0
# 8843                             0.00                             0
# 8905                             0.00                          0.66
#
# [175 rows x 14 columns]
